# %% [markdown]
# # TP CMB
# ## Graph number 1
# ### Gabriel Peytral Borja

# %%
import sys
from pathlib import Path

# Add project src/ to Python path so local modules can be imported from notebooks/
ROOT = Path.cwd().parent
SRC = ROOT / "src"

if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

print(f"Added to sys.path: {SRC}")
# Out:
# Added to sys.path: /Users/gabopb/Documents/M1S2/GRAPH/TP/src

# %%
import networkx as nx
from graph_analysis import analyze_graph_df, visualize_graph_analysis

# %% [markdown]
# ### Family name **P**eytral = Righmost graph
#
# 1. Minimal, maximal, and average degrees
# 2. Degree distribution
# 3. Diameter, radius, and average path length
# 4. Betweenness centrality
# 5. Google PageRank
# 6. Visualization

# %%
# Create a Graph
G = nx.Graph()
# Add edges
edges = [
    # Triangle-like structure
    (1, 2), (1, 4), (2, 3), (2, 4), (3, 4), 
    # Cube-like structure 1
    (4,13), (4, 5), (5, 6), (5, 11), (6, 7), (6, 10), (7, 8), (8, 9), (8, 10), (9, 11), (11, 10), 
    # Cube-like structure 2
    (11, 12), (12, 13), (12, 15), (15, 16), (15, 14), (16, 17), (17,14), (17,18), (17, 14), (14,13), (13,18)
]
G.add_edges_from(edges)

# %%
results = analyze_graph_df(G, name="Rightmost graph")

for key, value in results.items():
    print(f"\n=== {key} ===")
    display(value)
# Out:
# === name ===
# 'Rightmost graph'
# === graph_info ===
#             metric            value
# 0       graph_name  Rightmost graph
# 1  number_of_nodes               18
# 2  number_of_edges               26
# 3     is_connected             True
# === degree_stats ===
#            metric     value
# 0  minimal_degree  2.000000
# 1  maximal_degree  5.000000
# 2  average_degree  2.888889
# === degree_distribution ===
#    degree  count
# 0       2      6
# 1       3      9
# 2       4      2
# 3       5      1
# === distance_metrics ===
#                 metric     value computed_on
# 0             diameter  6.000000  full graph
# 1               radius  4.000000  full graph
# 2  average_path_length  2.908497  full graph
# === betweenness_centrality ===
#     node  betweenness_centrality
# 0      4                0.400735
# 1     13                0.323529
# 2     11                0.301471
# 3      5                0.259191
# 4     12                0.250000
# ...

# %%
visualize_graph_analysis(G, results, name="Rightmost graph")
